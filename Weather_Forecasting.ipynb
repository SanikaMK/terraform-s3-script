# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
data = pd.read_csv("DailyDelhiClimateTrain.csv")
data.head()

# %%
print(data.describe())
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB
# None

# %%
figure = px.line(data, x = "date",
                y = "meantemp",
                title = 'Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x = "date",
                y = "humidity",
                title = 'Humidity in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x = "date",
                y = "wind_speed",
                title = 'Wind Speed in Delhi Over the Years')
figure.show()

# %%
#pip install statsmodels

# %%
figure = px.scatter(data_frame = data, x="humidity",
                    y="meantemp", size="meantemp", 
                    trendline="ols", 
                    title = "Relationship Between Temperature and Humidity")
figure.show()

# %% [markdown]
# **Analyzing Temperature Chage**

# %%
import datetime
data["date"] = pd.to_datetime(data["date"], format = '%Y-%m-%d')
data['year'] = data['date'].dt.year
data["month"] = data["date"].dt.month
print(data.head())
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize = (15,10))
plt.title("Temperature Change in Delhi Over the Years")
sns.lineplot(data = data, x='month', y='meantemp', hue='year')
plt.show()

# %% [markdown]
# **Forecasting Weather using Python**

# %%
forecast_data = data.rename(columns = {"date": "ds",
                                      "meantemp": "y"})
forecast_data.head()

# %%
pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/14.4 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 11.5/14.4 MB 180.7 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 14.4/14.4 MB 218.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 111.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/venv/lib/python3.9/site-packages (from prophet) (3.7.0)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.2.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.36.1 in /opt/venv/lib/python3.9/site-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /opt/venv/lib/python3.9/site-packages (from prophet) (5.12.0)
# Collecting holidays>=0.25
#   Downloading holidays-0.37-py3-none-any.whl (851 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.0/852.0 kB 82.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in /opt/venv/lib/python3.9/site-packages (from prophet) (1.23.5)
# Requirement already satisfied: pandas>=1.0.4 in /opt/venv/lib/python3.9/site-packages (from prophet) (1.5.3)
# Collecting stanio~=0.3.0
#   Downloading stanio-0.3.0-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: python-dateutil in /opt/venv/lib/python3.9/site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (4.40.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (1.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/venv/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /opt/venv/lib/python3.9/site-packages (from importlib-resources->prophet) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.9/site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.9/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Installing collected packages: stanio, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.0 holidays-0.37 prophet-1.1.5 stanio-0.3.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
model = Prophet()
model.fit(forecast_data)
forecasts = model.make_future_dataframe(periods=365)
predictions = model.predict(forecasts)
plot_plotly(model, predictions)
# Out:
# 01:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 01:33:54 - cmdstanpy - INFO - Chain [1] done processing
